# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./Data/Hospital_Inpatient_Discharges.csv', low_memory=False)

# %%
df.head()
# Out:
#   Hospital Service Area Hospital County  Operating Certificate Number  \
# 0         New York City           Bronx                     7000006.0
# 1         New York City           Bronx                     7000006.0
# 2         New York City           Bronx                     7000006.0
# 3         New York City           Bronx                     7000006.0
# 4         New York City           Bronx                     7000006.0
#
#    Permanent Facility Id                                      Facility Name  \
# 0                 3058.0  Montefiore Med Center - Jack D Weiler Hosp of ...
# 1                 3058.0  Montefiore Med Center - Jack D Weiler Hosp of ...
# 2                 3058.0  Montefiore Med Center - Jack D Weiler Hosp of ...
# 3                 3058.0  Montefiore Med Center - Jack D Weiler Hosp of ...
# 4                 1168.0       Montefiore Medical Center-Wakefield Hospital
#
#   Age Group Zip Code - 3 digits Gender                    Race  \
# 0  50 to 69                 107      F                   White
# 1  18 to 29                 104      M  Black/African American
# 2  18 to 29                 104      F              Other Race
# 3  18 to 29                 100      F  Black/African American
# 4  18 to 29                 104      M              Other Race
#
#            Ethnicity  ... APR Severity of Illness Description  \
# 0  Not Span/Hispanic  ...                               Major
# 1   Spanish/Hispanic  ...                            Moderate
# 2   Spanish/Hispanic  ...                               Minor
# 3  Not Span/Hispanic  ...                            Moderate
# 4   Spanish/Hispanic  ...                            Moderate
#
#   APR Risk of Mortality APR Medical Surgical Description  Payment Typology 1  \
# 0                 Major                          Medical            Medicaid
# 1                 Minor                          Medical            Medicaid
# 2                 Minor                          Medical            Medicaid
# 3                 Minor                          Medical            Medicaid
# 4              Moderate                          Medical            Medicaid
#
#   Payment Typology 2 Payment Typology 3 Birth Weight  \
# 0                NaN                NaN          NaN
# 1                NaN                NaN          NaN
# 2                NaN                NaN          NaN
# 3                NaN                NaN          NaN
# 4                NaN                NaN          NaN
#
#   Emergency Department Indicator  Total Charges Total Costs
# 0                              Y      51,514.62    7,552.54
# 1                              Y      25,370.86    3,469.55
# 2                              N      23,876.78    6,180.33
# 3                              Y      43,319.05   12,588.93
# 4                              Y      40,266.23   10,355.99
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2103433 entries, 0 to 2103432
# Data columns (total 33 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   Hospital Service Area                object
#  1   Hospital County                      object
#  2   Operating Certificate Number         float64
#  3   Permanent Facility Id                float64
#  4   Facility Name                        object
#  5   Age Group                            object
#  6   Zip Code - 3 digits                  object
#  7   Gender                               object
#  8   Race                                 object
#  9   Ethnicity                            object
#  10  Length of Stay                       object
#  11  Type of Admission                    object
#  12  Patient Disposition                  object
#  13  Discharge Year                       int64
#  14  CCSR Diagnosis Code                  object
#  15  CCSR Diagnosis Description           object
#  16  CCSR Procedure Code                  object
#  17  CCSR Procedure Description           object
#  18  APR DRG Code                         int64
#  19  APR DRG Description                  object
#  20  APR MDC Code                         int64
#  21  APR MDC Description                  object
#  22  APR Severity of Illness Code         int64
#  23  APR Severity of Illness Description  object
#  24  APR Risk of Mortality                object
#  25  APR Medical Surgical Description     object
#  26  Payment Typology 1                   object
#  27  Payment Typology 2                   object
#  28  Payment Typology 3                   object
#  29  Birth Weight                         object
#  30  Emergency Department Indicator       object
#  31  Total Charges                        object
#  32  Total Costs                          object
# dtypes: float64(2), int64(4), object(27)
# memory usage: 529.6+ MB

# %%
df.describe()
# Out:
#        Operating Certificate Number  Permanent Facility Id  Discharge Year  \
# count                  2.097472e+06           2.098043e+06       2103433.0
# mean                   5.038452e+06           1.042746e+03          2022.0
# std                    2.247117e+06           7.311661e+02             0.0
# min                    1.010000e+05           1.000000e+00          2022.0
# 25%                    2.952005e+06           5.410000e+02          2022.0
# 50%                    5.907002e+06           1.072000e+03          2022.0
# 75%                    7.002024e+06           1.453000e+03          2022.0
# max                    7.004010e+06           1.035500e+04          2022.0
#
#        APR DRG Code  APR MDC Code  APR Severity of Illness Code
# count  2.103433e+06  2.103433e+06                  2.103433e+06
# mean   4.133186e+02  1.029289e+01                  2.146218e+00
# std    2.437523e+02  5.967575e+00                  9.624234e-01
# min    1.000000e+00  0.000000e+00                  0.000000e+00
# 25%    1.940000e+02  5.000000e+00                  1.000000e+00
# 50%    3.830000e+02  9.000000e+00                  2.000000e+00
# 75%    6.400000e+02  1.500000e+01                  3.000000e+00
# max    9.560000e+02  2.500000e+01                  4.000000e+00

# %%
df.isnull().sum()
# Out:
# Hospital Service Area                     5390
# Hospital County                           5390
# Operating Certificate Number              5961
# Permanent Facility Id                     5390
# Facility Name                                0
# Age Group                                    0
# Zip Code - 3 digits                      41227
# Gender                                       0
# Race                                         0
# Ethnicity                                    0
# Length of Stay                               0
# Type of Admission                            0
# Patient Disposition                          0
# Discharge Year                               0
# CCSR Diagnosis Code                          0
# CCSR Diagnosis Description                   0
# CCSR Procedure Code                     582815
# CCSR Procedure Description              582815
# APR DRG Code                                 0
# APR DRG Description                          0
# APR MDC Code                                 0
# APR MDC Description                          0
# APR Severity of Illness Code                 0
# APR Severity of Illness Description        636
# APR Risk of Mortality                      636
# APR Medical Surgical Description             0
# Payment Typology 1                           0
# Payment Typology 2                     1121497
# Payment Typology 3                     1814362
# Birth Weight                           1894796
# Emergency Department Indicator               0
# Total Charges                                0
# Total Costs                                  0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Hospital Service Area', 'Hospital County',
#        'Operating Certificate Number', 'Permanent Facility Id',
#        'Facility Name', 'Age Group', 'Zip Code - 3 digits', 'Gender', 'Race',
#        'Ethnicity', 'Length of Stay', 'Type of Admission',
#        'Patient Disposition', 'Discharge Year', 'CCSR Diagnosis Code',
#        'CCSR Diagnosis Description', 'CCSR Procedure Code',
#        'CCSR Procedure Description', 'APR DRG Code', 'APR DRG Description',
#        'APR MDC Code', 'APR MDC Description', 'APR Severity of Illness Code',
#        'APR Severity of Illness Description', 'APR Risk of Mortality',
#        'APR Medical Surgical Description', 'Payment Typology 1',
#        'Payment Typology 2', 'Payment Typology 3', 'Birth Weight',
#        'Emergency Department Indicator', 'Total Charges', 'Total Costs'],
#       dtype='object')

# %%
df = df.drop(columns=['Operating Certificate Number', 'CCSR Diagnosis Code', 'CCSR Procedure Code', 'APR DRG Code', 
                      'APR MDC Code', 'APR Severity of Illness Code', 'Payment Typology 2', 'Payment Typology 3', 'CCSR Procedure Description'])

# %%
df.isnull().sum()
# Out:
# Hospital Service Area                     5390
# Hospital County                           5390
# Permanent Facility Id                     5390
# Facility Name                                0
# Age Group                                    0
# Zip Code - 3 digits                      41227
# Gender                                       0
# Race                                         0
# Ethnicity                                    0
# Length of Stay                               0
# Type of Admission                            0
# Patient Disposition                          0
# Discharge Year                               0
# CCSR Diagnosis Description                   0
# APR DRG Description                          0
# APR MDC Description                          0
# APR Severity of Illness Description        636
# APR Risk of Mortality                      636
# APR Medical Surgical Description             0
# Payment Typology 1                           0
# Birth Weight                           1894796
# Emergency Department Indicator               0
# Total Charges                                0
# Total Costs                                  0
# dtype: int64

# %%
df = df.dropna(subset=['APR Severity of Illness Description'])
df = df.dropna(subset=['APR Risk of Mortality'])
df = df.dropna(subset=['Zip Code - 3 digits'])
df = df.dropna(subset=['Hospital Service Area'])
df = df.dropna(subset=['Hospital County'])
df = df.dropna(subset=['APR DRG Description'])
df = df.dropna(subset=['Permanent Facility Id'])

# %%
df.isnull().sum()
# Out:
# Hospital Service Area                        0
# Hospital County                              0
# Permanent Facility Id                        0
# Facility Name                                0
# Age Group                                    0
# Zip Code - 3 digits                          0
# Gender                                       0
# Race                                         0
# Ethnicity                                    0
# Length of Stay                               0
# Type of Admission                            0
# Patient Disposition                          0
# Discharge Year                               0
# CCSR Diagnosis Description                   0
# APR DRG Description                          0
# APR MDC Description                          0
# APR Severity of Illness Description          0
# APR Risk of Mortality                        0
# APR Medical Surgical Description             0
# Payment Typology 1                           0
# Birth Weight                           1856607
# Emergency Department Indicator               0
# Total Charges                                0
# Total Costs                                  0
# dtype: int64

# %%
df.shape
# Out:
# (2061584, 24)

# %%
df['Hospital County'].unique()
# Out:
# array(['Bronx', 'Rockland', 'Manhattan', 'Westchester', 'Kings', 'Queens',
#        'Orange', 'Nassau', 'Sullivan', 'Otsego', 'Herkimer', 'Delaware',
#        'Monroe', 'Ontario', 'Cortland', 'Columbia', 'Albany', 'Suffolk',
#        'Onondaga', 'Madison', 'Steuben', 'Cayuga', 'Montgomery', 'Erie',
#        'Jefferson', 'Oswego', 'Yates', 'Wayne', 'Genesee', 'Schoharie',
#        'Ulster', 'Oneida', 'Schenectady', 'Broome', 'St Lawrence',
#        'Schuyler', 'Richmond', 'Niagara', 'Chemung', 'Essex',
#        'Chautauqua', 'Dutchess', 'Putnam', 'Chenango', 'Tompkins',
#        'Warren', 'Fulton', 'Wyoming', 'Franklin', 'Cattaraugus',
#        'Saratoga', 'Lewis', 'Livingston', 'Allegany', 'Orleans',
#        'Clinton', 'Rensselaer'], dtype=object)

# %%
county_to_region = {
    'Bronx': 'South', 'Rockland': 'East', 'Manhattan': 'South', 'Westchester': 'East',
    'Kings': 'South', 'Queens': 'South', 'Orange': 'East', 'Nassau': 'South',
    'Sullivan': 'East', 'Otsego': 'North', 'Herkimer': 'North', 'Delaware': 'East',
    'Monroe': 'West', 'Ontario': 'West', 'Cortland': 'North', 'Columbia': 'East',
    'Albany': 'East', 'Suffolk': 'East', 'Onondaga': 'North', 'Madison': 'North',
    'Steuben': 'West', 'Cayuga': 'North', 'Montgomery': 'North', 'Erie': 'West',
    'Jefferson': 'North', 'Oswego': 'North', 'Yates': 'North', 'Wayne': 'West',
    'Genesee': 'West', 'Schoharie': 'North', 'Ulster': 'East', 'Oneida': 'North',
    'Schenectady': 'North', 'Broome': 'West', 'St Lawrence': 'North', 'Schuyler': 'West',
    'Richmond': 'South', 'Niagara': 'West', 'Chemung': 'West', 'Essex': 'North',
    'Chautauqua': 'West', 'Dutchess': 'East', 'Putnam': 'East', 'Chenango': 'North',
    'Tompkins': 'West', 'Warren': 'North', 'Fulton': 'North', 'Wyoming': 'West',
    'Franklin': 'North', 'Cattaraugus': 'West', 'Saratoga': 'North', 'Lewis': 'North',
    'Livingston': 'West', 'Allegany': 'West', 'Orleans': 'West', 'Clinton': 'North',
    'Rensselaer': 'East'
}

df['Region'] = df['Hospital County'].map(county_to_region)

# %%
# Function to generate birth weight based on gender, rounded to the nearest 100 gm
def generate_birth_weight(row):
    if row['Gender'] == 'F':  
        return np.random.choice(range(3100, 3301, 100))  
    elif row['Gender'] == 'M':  
        return np.random.choice(range(3300, 3701, 100))  
    else:
        return np.nan  # If gender is unknown, set as NaN

df['Birth Weight'] = df.apply(generate_birth_weight, axis=1)

df['Birth Weight'] = df['Birth Weight'].apply(lambda x: f'{int(x):04d}' if pd.notna(x) else x)

print(df[['Gender', 'Birth Weight']].head())
# Out:
#   Gender Birth Weight
# 0      F         3300
# 1      M         3300
# 2      F         3300
# 3      F         3100
# 4      M         3500

# %%
missing_values_by_gender = df.groupby('Gender')['Birth Weight'].apply(lambda x: x.isnull().sum())

print(missing_values_by_gender)
# Out:
# Gender
# F      0
# M      0
# U    103
# Name: Birth Weight, dtype: int64

# %%
df = df.dropna(subset=['Birth Weight'])

# %%
df.isnull().sum()
# Out:
# Hospital Service Area                  0
# Hospital County                        0
# Permanent Facility Id                  0
# Facility Name                          0
# Age Group                              0
# Zip Code - 3 digits                    0
# Gender                                 0
# Race                                   0
# Ethnicity                              0
# Length of Stay                         0
# Type of Admission                      0
# Patient Disposition                    0
# Discharge Year                         0
# CCSR Diagnosis Description             0
# APR DRG Description                    0
# APR MDC Description                    0
# APR Severity of Illness Description    0
# APR Risk of Mortality                  0
# APR Medical Surgical Description       0
# Payment Typology 1                     0
# Birth Weight                           0
# Emergency Department Indicator         0
# Total Charges                          0
# Total Costs                            0
# Region                                 0
# dtype: int64

# %%
df.shape
# Out:
# (2061481, 25)

# %%
df['CCSR Diagnosis Description'].unique()
# Out:
# array(['COVID-19', 'Skin and subcutaneous tissue infections',
#        'Previous C-section', 'Prolonged pregnancy',
#        'Schizophrenia spectrum and other psychotic disorders',
#        'Acute bronchitis', 'Retinal and vitreous conditions',
#        'Acute and unspecified renal failure',
#        'Drug induced or toxic related condition',
#        'Complications specified during childbirth',
#        'Other nervous system disorders (often hereditary or degenerative)',
#        'Malposition, disproportion or other labor complications',
#        'Hypertension and hypertensive-related conditions complicating pregnancy; childbirth; and the puerperium',
#        'Hypertension with complications and secondary hypertension',
#        'Epilepsy; convulsions', 'Esophageal disorders',
#        'Intestinal infection', 'Asthma', 'Alcohol-related disorders',
#        'Early or threatened labor', 'Gastritis and duodenitis',
#        'Heart failure', 'Pancreatic disorders (excluding diabetes)',
#        'Septicemia', 'Noninfectious gastroenteritis', 'Liveborn',
#        'Spondylopathies/spondyloarthropathy (including infective)',
#        'Other specified complications in pregnancy',
#        'Other specified and unspecified liver disease',
#        'Complication of other surgical or medical care, injury, initial encounter',
#        'Maternal care related to fetal conditions',
#        'Fracture of the spine and back, initial encounter',
#        'Sickle cell trait/anemia', 'Fluid and electrolyte disorders',
#        'Neurocognitive disorders', 'Respiratory signs and symptoms',
#        'Other specified and unspecified gastrointestinal disorders',
#        'Acute pulmonary embolism',
#        'Other specified upper respiratory infections', 'Abdominal hernia',
#        'Varicose veins of lower extremity',
#        'Headache; including migraine', 'Cerebral infarction',
#        'Osteomyelitis',
#        'Traumatic brain injury (TBI); concussion, initial encounter',
#        'Disruptive, impulse-control and conduct disorders',
#        'Chronic kidney disease',
#        'Other specified and unspecified skin disorders',
#        'Other specified injury',
#        'Postprocedural or postoperative digestive system complication',
#        'Encounter for antineoplastic therapies', 'Obesity',
#        'Osteoporosis', 'Pneumonia (except that caused by tuberculosis)',
#        'Urinary tract infections',
#        'Postthrombotic syndrome and venous insufficiency/hypertension',
#        'Diabetes mellitus with complication', 'Syncope',
#        'Secondary malignancies', 'Intestinal obstruction and ileus',
#        'Postprocedural or postoperative respiratory system complication',
#        'Circulatory signs and symptoms',
#        'Uncomplicated pregnancy, delivery or puerperium',
#        'Other specified and unspecified nutritional and metabolic disorders',
#        'Myopathies',
#        'Diabetes or abnormal glucose tolerance complicating pregnancy; childbirth; or the puerperium',
#        'Complication of genitourinary device, implant or graft, initial encounter',
#        'Fracture of head and neck, initial encounter',
#        'Other specified and unspecified diseases of kidney and ureters',
#        'Hypotension', 'Muscle disorders', 'Acute myocardial infarction',
#        'Bipolar and related disorders', 'Depressive disorders',
#        'Malignant neuroendocrine tumors',
#        'Head and neck cancers - nasopharyngeal', 'Non-Hodgkin lymphoma',
#        'Fracture of torso, initial encounter', 'Influenza',
#        'Fracture of the upper limb, initial encounter',
#        'Fracture of the lower limb (except hip), initial encounter',
#        'Appendicitis and other appendiceal conditions',
#        'Abdominal pain and other digestive/abdomen signs and symptoms',
#        'Biliary tract disease', 'Diverticulosis and diverticulitis',
#        'Nervous system signs and symptoms',
#        'Male reproductive system cancers - prostate',
#        'Opioid-related disorders', 'Cardiac dysrhythmias',
#        'Chronic rheumatic heart disease',
#        'Open wounds to limbs, initial encounter',
#        'Diseases of mouth; excluding dental',
#        'OB-related trauma to perineum and vulva',
#        'Maternal care related to disorders of the placenta and placental implantation',
#        'Poisoning by drugs, initial encounter',
#        'Fracture of the neck of the femur (hip), initial encounter',
#        'Peritonitis and intra-abdominal abscess',
#        'Acute phlebitis; thrombophlebitis and thromboembolism',
#        'Diseases of middle ear and mastoid (except otitis media)',
#        'Acute hemorrhagic cerebrovascular disease',
#        'Pathological fracture, initial encounter',
#        'Gastrointestinal hemorrhage',
#        'Complication of internal orthopedic device or implant, initial encounter',
#        'Sequela of cerebral infarction and other cerebrovascular disease',
#        'Respiratory failure; insufficiency; arrest',
#        'Other specified substance-related disorders', 'Viral infection',
#        'Aspiration pneumonitis', 'Multiple gestation', 'Osteoarthritis',
#        'Gastrointestinal cancers - stomach',
#        'Complication of cardiovascular device, implant or graft, initial encounter',
#        'Nutritional anemia',
#        'Nonrheumatic and unspecified valve disorders',
#        'Non-pressure ulcer of skin',
#        'Other specified and unspecified lower respiratory disease',
#        'Encephalitis', 'Peripheral and visceral vascular disease',
#        'Musculoskeletal congenital conditions',
#        'Chronic obstructive pulmonary disease and bronchiectasis',
#        'Nervous system congenital anomalies',
#        'Breast cancer - all other types', 'Thyroid disorders',
#        'Postprocedural or postoperative circulatory system complication',
#        'Polyhydramnios and other problems of amniotic cavity',
#        'Complication of transplanted organs or tissue, initial encounter',
#        'Pulmonary heart disease', 'Fever', 'Bacterial infections',
#        'Nonspecific chest pain',
#        'Head and neck cancers - all other types',
#        'Coronary atherosclerosis and other heart disease',
#        'Female reproductive system cancers - endometrium',
#        'Diseases of inner ear and related conditions', 'Cystic fibrosis',
#        'Other general signs and symptoms',
#        'Tendon and synovial disorders', 'Hepatic failure',
#        'Endocarditis and endocardial disease', 'Gastroduodenal ulcer',
#        'Benign ovarian cyst', 'Acquired deformities (excluding foot)',
#        'Abnormal findings without diagnosis',
#        'Cardiac and circulatory congenital anomalies',
#        'Gastrointestinal cancers - liver',
#        'Other specified female genital disorders',
#        'Disorders of teeth and gingiva', 'Nervous system cancers - brain',
#        'Acute posthemorrhagic anemia',
#        'Systemic lupus erythematosus and connective tissue disorders',
#        'Trauma- and stressor-related disorders', 'Gout',
#        'Regional enteritis and ulcerative colitis', 'Pneumothorax',
#        'Parkinson`s disease', 'Aplastic anemia', 'Sleep wake disorders',
#        'Gastrointestinal cancers - colorectal',
#        'Conditions due to neoplasm or the treatment of neoplasm',
#        'Occlusion or stenosis of precerebral or cerebral arteries without infarction',
#        'Maltreatment/abuse', 'Lung disease due to external agents',
#        'Myelodysplastic syndrome (MDS)', 'Other aftercare encounter',
#        'Other specified and unspecified mood disorders',
#        'Malaise and fatigue', 'Paralysis (other than cerebral palsy)',
#        'Respiratory cancers',
#        'Head and neck cancers - lip and oral cavity', 'Polyneuropathies',
#        'Cardiac arrest and ventricular fibrillation', 'Multiple myeloma',
#        'Endocrine system cancers - pancreas',
#        'Aortic; peripheral; and visceral artery aneurysms',
#        'Disorders of jaw',
#        'Other nervous system disorders (neither hereditary nor degenerative)',
#        'Traumatic arthropathy',
#        'Maternal care for abnormality of pelvic organs',
#        'Transient cerebral ischemia',
#        'Coagulation and hemorrhagic disorders', 'Benign neoplasms',
#        'Anal and rectal conditions',
#        'Pericarditis and pericardial disease',
#        'Nerve and nerve root disorders',
#        'Complications specified during the puerperium',
#        'Diseases of white blood cells',
#        'Leukemia - acute myeloid leukemia (AML)',
#        'Pleurisy, pleural effusion and pulmonary collapse', 'Hepatitis',
#        'Nausea and vomiting', 'Stress fracture, initial encounter',
#        'Postprocedural or postoperative skin complication',
#        'Other specified and unspecified diseases of bladder and urethra',
#        'Symptoms of mental and substance use conditions',
#        'Stimulant-related disorders', 'Acute and chronic tonsillitis',
#        'Other specified bone disease and musculoskeletal deformities',
#        'Open wounds of head and neck, initial encounter',
#        'General sensation/perception signs and symptoms',
#        'Nervous system cancers - all other types',
#        'Scoliosis and other postural dorsopathic deformities',
#        'Other and ill-defined cerebrovascular disease',
#        'Leukemia - all other types',
#        'Internal organ injury, initial encounter',
#        'Superficial injury; contusion, initial encounter',
#        'Allergic reactions',
#        'Encounter for observation and examination for conditions ruled out (excludes infectious disease, neoplasm, mental disorders)',
#        'Low back pain', 'Inflammatory conditions of male genital organs',
#        'Musculoskeletal pain, not low back pain', 'Dysphagia',
#        'Neurodevelopmental disorders', 'Hemorrhoids', 'Cerebral palsy',
#        'Nephritis; nephrosis; renal sclerosis',
#        'Calculus of urinary tract',
#        'Suicidal ideation/attempt/intentional self-harm',
#        'Other specified status', 'Personality disorders', 'CNS abscess',
#        'Traumatic brain injury (TBI); concussion, subsequent encounter',
#        'Other specified and unspecified endocrine disorders',
#        'Pituitary disorders', 'Hyperplasia of prostate',
#        'Anxiety and fear-related disorders',
#        'Hemolytic jaundice and perinatal jaundice',
#        'Other specified diseases of veins and lymphatics',
#        'Other specified and unspecified disorders of the ear',
#        'Urinary system cancers - bladder',
#        'Effect of foreign body entering opening, initial encounter',
#        'Myocarditis and cardiomyopathy', 'Conduction disorders',
#        'Skin/Subcutaneous signs and symptoms',
#        'Other specified and unspecified upper respiratory disease',
#        'Inflammatory diseases of female pelvic organs',
#        'Obsessive-compulsive and related disorders',
#        'Fracture of lower limb (except hip), subsequent encounter',
#        'Urinary system cancers - kidney',
#        'Other specified and unspecified congenital anomalies',
#        'Fracture of torso, subsequent encounter',
#        'Nonmalignant breast conditions',
#        'Postprocedural or postoperative musculoskeletal system complication',
#        'Other specified and unspecified circulatory disease',
#        'Acquired foot deformities',
#        'Burn and corrosion, initial encounter', 'Fungal infections',
#        'Infective arthritis',
#        'Other specified inflammatory condition of skin',
#        'Other and ill-defined heart disease',
#        'Postprocedural or postoperative nervous system complication',
#        'Hemolytic anemia', 'Cannabis-related disorders',
#        'Blindness and vision defects', 'Neuro-ophthalmology',
#        'Sprains and strains, initial encounter',
#        'Neoplasms of unspecified nature or uncertain behavior',
#        'Breast cancer - ductal carcinoma in situ (DCIS)',
#        'Other specified and unspecified hematologic conditions',
#        'Other specified eye disorders',
#        'Gastrointestinal cancers - bile duct',
#        'Oculofacial plastics and orbital conditions',
#        'Burns and corrosion, subsequent encounter',
#        'Other specified and unspecified disorders of stomach and duodenum',
#        'Female reproductive system cancers - ovary',
#        'Arterial dissections', 'Maternal intrauterine infection',
#        'Other specified male genital disorders',
#        'Postprocedural or postoperative genitourinary system complication',
#        'Hemorrhage after first trimester',
#        'Head and neck cancers - laryngeal', 'Foodborne intoxications',
#        'Fracture of the neck of the femur (hip), subsequent encounter',
#        'Toxic effects, initial encounter', 'Hodgkin lymphoma',
#        'Mesothelioma', 'Coma; stupor; and brain damage',
#        'Other specified connective tissue disease',
#        'Open wounds of trunk, initial encounter', 'Multiple sclerosis',
#        'Shock', 'Effect of other external causes, initial encounter',
#        'Nervous system pain and pain syndromes', 'Perinatal infections',
#        'Injury, sequela', 'Female reproductive system cancers - uterus',
#        'Meningitis', 'Early, first or unspecified trimester hemorrhage',
#        'Other specified joint disorders',
#        'Injury to nerves, muscles and tendons, initial encounter',
#        'Gangrene', 'Gastrointestinal cancers - esophagus',
#        'Open wounds of trunk, subsequent encounter',
#        'Rheumatoid arthritis and related disease',
#        'Essential hypertension', 'Somatic disorders',
#        'Menstrual disorders', 'Feeding and eating disorders',
#        'Crystal arthropathies (excluding gout)',
#        'Other unspecified injury',
#        'Short gestation; low birth weight; and fetal growth retardation',
#        'Mental and substance use disorders in remission',
#        'Head and neck cancers - eye', 'Digestive congenital anomalies',
#        'Respiratory perinatal condition',
#        'Other specified and unspecified perinatal conditions', 'Sarcoma',
#        'Cancer of other sites', 'Sinusitis', 'Nutritional deficiencies',
#        'Respiratory congenital malformations', 'Bone cancer',
#        'Endometriosis', 'Neonatal cerebral disorders',
#        'Neonatal digestive and feeding disorders',
#        'Sexually transmitted infections (excluding HIV and hepatitis)',
#        'Aseptic necrosis and osteonecrosis', 'Sedative-related disorders',
#        'Genitourinary congenital anomalies',
#        'Sequela of hemorrhagic cerebrovascular disease',
#        'Injury to blood vessels, initial encounter',
#        'Pressure ulcer of skin',
#        'Female reproductive system cancers - vagina',
#        'Gastrointestinal and biliary perforation', 'Hematuria',
#        'Female reproductive system cancers - vulva', 'Otitis media',
#        'Endocrine system cancers - thyroid',
#        'Gastrointestinal cancers - anus',
#        'Miscellaneous mental and behavioral disorders/conditions',
#        'Head and neck cancers - tonsils',
#        'Head and neck cancers - hypopharyngeal',
#        'Skin cancers - all other types', 'Skin cancers - melanoma',
#        'Immunity disorders',
#        'Encounter for prophylactic or other procedures',
#        'Complication of internal orthopedic device or implant, subsequent encounter',
#        'Head and neck cancers - salivary gland',
#        'Skin cancers - squamous cell carcinoma',
#        'Female reproductive system cancers - fallopian tube',
#        'Complications of acute myocardial infarction',
#        'Immune-mediated/reactive arthropathies',
#        'Aortic and peripheral arterial embolism or thrombosis',
#        'Tuberculosis', 'Malnutrition',
#        'Sprains and strains, subsequent encounter',
#        'Genitourinary signs and symptoms',
#        'Gastrointestinal cancers - all other types',
#        'Gastrointestinal cancers - gallbladder', 'Urinary incontinence',
#        'Birth trauma', 'Malignant neoplasm, unspecified',
#        'Cleft lip or palate', 'Cornea and external disease',
#        'Spinal cord injury (SCI), initial encounter',
#        'Leukemia - acute lymphoblastic leukemia (ALL)',
#        'Dislocations, initial encounter',
#        'Gastrointestinal cancers - small intestine',
#        'Disorders of lipid metabolism', 'Biomechanical lesions',
#        'Fracture of the upper limb, subsequent encounter',
#        'Hallucinogen-related disorders',
#        'Crushing injury, initial encounter',
#        'Female reproductive system cancers - cervix',
#        'Prolapse of female genital organs',
#        'Dislocations, subsequent encounter',
#        'Urinary system cancers - all other types',
#        'Endocrine system cancers - adrenocortical',
#        'Implant, device or graft related encounter',
#        'Leukemia - chronic myeloid leukemia (CML)',
#        'Mediastinal disorders', 'Menopausal disorders',
#        'Noninfectious hepatitis',
#        'Exposure, encounters, screening or contact with infectious disease',
#        'Fracture of the spine and back, subsequent encounter',
#        'Acquired absence of limb or organ', 'Vesicoureteral reflux',
#        'Male reproductive system cancers - testis',
#        'Uveitis and ocular inflammation',
#        'Endocrine system cancers - thymus',
#        'Parasitic, other specified and unspecified infections',
#        'Male reproductive system cancers - penis',
#        'Toxic effects, subsequent encounter', 'Cardiac cancers',
#        'Stress fracture, subsequent encounter',
#        'Complication of cardiovascular device, implant or graft, subsequent encounter',
#        'Pathological fracture, subsequent encounter',
#        'Complication of genitourinary device, implant or graft, subsequent encounter',
#        'Complication of other surgical or medical care, injury, subsequent encounter',
#        'Open wounds of head and neck, subsequent encounter', 'Glaucoma',
#        'Diabetes mellitus without complication',
#        'Amputation of a limb, subsequent encounter',
#        'Endocrine system cancers - all other types',
#        'Neoplasm-related encounters', 'Leukemia - hairy cell',
#        'Endocrine system cancers - parathyroid',
#        'Urinary system cancers - ureter and renal pelvis',
#        'Female reproductive system cancers - all other types',
#        'Amputation of a limb, initial encounter',
#        'Atypical fracture, initial encounter',
#        'Spinal cord injury (SCI), subsequent encounter',
#        'Contact dermatitis', 'Atypical fracture, subsequent encounter',
#        'Respiratory distress syndrome',
#        'Hemorrhagic and hematologic disorders of newborn',
#        'Congenital malformations of eye, ear, face, neck',
#        'Gastrointestinal cancers - peritoneum',
#        'Leukemia - chronic lymphocytic leukemia (CLL)',
#        'Musculoskeletal abscess', 'Neonatal abstinence syndrome',
#        'Other specified CNS infection and poliomyelitis',
#        'Postprocedural or postoperative endocrine or metabolic complication',
#        'Obstetric history affecting care in pregnancy',
#        'Head and neck cancers - throat',
#        'Chronic phlebitis; thrombophlebitis and thromboembolism',
#        'Erectile dysfunction', 'Cataract and other lens disorders',
#        'Newborn affected by maternal conditions or complications of labor/delivery',
#        'Pathological, stress and atypical fractures, sequela',
#        'Head and neck cancers - pharyngeal',
#        'Neonatal acidemia and hypoxia',
#        'Internal organ injury, subsequent encounter',
#        'Postprocedural or postoperative complications of the spleen',
#        'Amputation of other body parts, initial encounter',
#        'Other unspecified injuries, subsequent encounter',
#        'Male infertility', 'Juvenile arthritis',
#        'Medical examination/evaluation',
#        'Male reproductive system cancers - all other types',
#        'Proteinuria',
#        'Adverse effects of drugs and medicaments, initial encounter',
#        'Other specified injury, subsequent encounter',
#        'Fracture of head and neck, subsequent encounter',
#        'Neurogenic/neuropathic arthropathy',
#        'Injury to blood vessels, subsequent encounter',
#        'Open wounds to limbs, subsequent encounter',
#        'Contraceptive and procreative management',
#        'Postprocedural or postoperative ear and/or mastoid process complication',
#        'Urinary system cancers - urethra', 'Chromosomal abnormalities',
#        'Effect of other external causes, subsequent encounter',
#        'Endocrine system cancers - pituitary gland', 'Hearing loss',
#        'Encounter for mental health conditions',
#        'Skin cancers - basal cell carcinoma',
#        'Poisoning by drugs, subsequent encounter',
#        'Suicide attempt/intentional self-harm; subsequent encounter',
#        'Strabismus', 'Acute rheumatic heart disease',
#        'Effect of foreign body entering opening, subsequent encounter',
#        'Inhalant-related disorders',
#        'Anesthesia complications during pregnancy', 'Antenatal screening',
#        'Postprocedural or postoperative eye complication',
#        'Complication, sequela',
#        'Superficial injury; contusion, subsequent encounter',
#        'Injury to nerves, muscles and tendons, subsequent encounter',
#        'Autoinflammatory syndromes',
#        'Effect of other external causes, sequela',
#        'Lifestyle/life management factors',
#        'Sequela of specified nervous system conditions',
#        'Maltreatment/abuse, subsequent encounter',
#        'Crushing injury, subsequent encounter',
#        'Poisoning/toxic effect/adverse effects/underdosing, sequela',
#        'Female infertility', 'Refractive error', 'Osteomalacia',
#        'Encounter for mental health services related to abuse',
#        'Sequela of specified infectious disease conditions',
#        'Other specified chronic arthropathy',
#        'Allergic reactions, subsequent encounter',
#        'Tobacco-related disorders',
#        'Other specified encounters and counseling', 'Unacceptable PDX'],
#       dtype=object)

# %%
# Modify column names: convert to lowercase, replace spaces with underscores, and remove hyphens
df.columns = df.columns.str.replace(' ', '_').str.replace('-', '').str.upper()

# %%
df.head()
# Out:
#   HOSPITAL_SERVICE_AREA HOSPITAL_COUNTY  PERMANENT_FACILITY_ID  \
# 0         New York City           Bronx                 3058.0
# 1         New York City           Bronx                 3058.0
# 2         New York City           Bronx                 3058.0
# 3         New York City           Bronx                 3058.0
# 4         New York City           Bronx                 1168.0
#
#                                        FACILITY_NAME AGE_GROUP  \
# 0  Montefiore Med Center - Jack D Weiler Hosp of ...  50 to 69
# 1  Montefiore Med Center - Jack D Weiler Hosp of ...  18 to 29
# 2  Montefiore Med Center - Jack D Weiler Hosp of ...  18 to 29
# 3  Montefiore Med Center - Jack D Weiler Hosp of ...  18 to 29
# 4       Montefiore Medical Center-Wakefield Hospital  18 to 29
#
#   ZIP_CODE__3_DIGITS GENDER                    RACE          ETHNICITY  \
# 0                107      F                   White  Not Span/Hispanic
# 1                104      M  Black/African American   Spanish/Hispanic
# 2                104      F              Other Race   Spanish/Hispanic
# 3                100      F  Black/African American  Not Span/Hispanic
# 4                104      M              Other Race   Spanish/Hispanic
#
#   LENGTH_OF_STAY  ...                                APR_MDC_DESCRIPTION  \
# 0              3  ...   DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 1              1  ...  DISEASES AND DISORDERS OF THE SKIN, SUBCUTANEO...
# 2              2  ...           PREGNANCY, CHILDBIRTH AND THE PUERPERIUM
# 3              2  ...           PREGNANCY, CHILDBIRTH AND THE PUERPERIUM
# 4              4  ...                      MENTAL DISEASES AND DISORDERS
#
#   APR_SEVERITY_OF_ILLNESS_DESCRIPTION  APR_RISK_OF_MORTALITY  \
# 0                               Major                  Major
# 1                            Moderate                  Minor
# 2                               Minor                  Minor
# 3                            Moderate                  Minor
# 4                            Moderate               Moderate
#
#   APR_MEDICAL_SURGICAL_DESCRIPTION PAYMENT_TYPOLOGY_1 BIRTH_WEIGHT  \
# 0                          Medical           Medicaid         3300
# 1                          Medical           Medicaid         3300
# 2                          Medical           Medicaid         3300
# 3                          Medical           Medicaid         3100
# 4                          Medical           Medicaid         3500
#
#   EMERGENCY_DEPARTMENT_INDICATOR TOTAL_CHARGES TOTAL_COSTS REGION
# 0                              Y     51,514.62    7,552.54  South
# 1                              Y     25,370.86    3,469.55  South
# 2                              N     23,876.78    6,180.33  South
# 3                              Y     43,319.05   12,588.93  South
# 4                              Y     40,266.23   10,355.99  South
#
# [5 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['HOSPITAL_SERVICE_AREA', 'HOSPITAL_COUNTY', 'PERMANENT_FACILITY_ID',
#        'FACILITY_NAME', 'AGE_GROUP', 'ZIP_CODE__3_DIGITS', 'GENDER', 'RACE',
#        'ETHNICITY', 'LENGTH_OF_STAY', 'TYPE_OF_ADMISSION',
#        'PATIENT_DISPOSITION', 'DISCHARGE_YEAR', 'CCSR_DIAGNOSIS_DESCRIPTION',
#        'APR_DRG_DESCRIPTION', 'APR_MDC_DESCRIPTION',
#        'APR_SEVERITY_OF_ILLNESS_DESCRIPTION', 'APR_RISK_OF_MORTALITY',
#        'APR_MEDICAL_SURGICAL_DESCRIPTION', 'PAYMENT_TYPOLOGY_1',
#        'BIRTH_WEIGHT', 'EMERGENCY_DEPARTMENT_INDICATOR', 'TOTAL_CHARGES',
#        'TOTAL_COSTS', 'REGION'],
#       dtype='object')

# %%
# For column names
df.columns = df.columns.str.replace('__', '_').str.upper()

# %%
df.columns
# Out:
# Index(['HOSPITAL_SERVICE_AREA', 'HOSPITAL_COUNTY', 'PERMANENT_FACILITY_ID',
#        'FACILITY_NAME', 'AGE_GROUP', 'ZIP_CODE_3_DIGITS', 'GENDER', 'RACE',
#        'ETHNICITY', 'LENGTH_OF_STAY', 'TYPE_OF_ADMISSION',
#        'PATIENT_DISPOSITION', 'DISCHARGE_YEAR', 'CCSR_DIAGNOSIS_DESCRIPTION',
#        'APR_DRG_DESCRIPTION', 'APR_MDC_DESCRIPTION',
#        'APR_SEVERITY_OF_ILLNESS_DESCRIPTION', 'APR_RISK_OF_MORTALITY',
#        'APR_MEDICAL_SURGICAL_DESCRIPTION', 'PAYMENT_TYPOLOGY_1',
#        'BIRTH_WEIGHT', 'EMERGENCY_DEPARTMENT_INDICATOR', 'TOTAL_CHARGES',
#        'TOTAL_COSTS', 'REGION'],
#       dtype='object')

# %%
df.to_csv('cleaned_data.csv', index=False)

# %%
cleaned = pd.read_csv('./Data/cleaned_data.csv')

# %%
cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2061481 entries, 0 to 2061480
# Data columns (total 25 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   HOSPITAL_SERVICE_AREA                object
#  1   HOSPITAL_COUNTY                      object
#  2   PERMANENT_FACILITY_ID                float64
#  3   FACILITY_NAME                        object
#  4   AGE_GROUP                            object
#  5   ZIP_CODE_3_DIGITS                    object
#  6   GENDER                               object
#  7   RACE                                 object
#  8   ETHNICITY                            object
#  9   LENGTH_OF_STAY                       object
#  10  TYPE_OF_ADMISSION                    object
#  11  PATIENT_DISPOSITION                  object
#  12  DISCHARGE_YEAR                       int64
#  13  CCSR_DIAGNOSIS_DESCRIPTION           object
#  14  APR_DRG_DESCRIPTION                  object
#  15  APR_MDC_DESCRIPTION                  object
#  16  APR_SEVERITY_OF_ILLNESS_DESCRIPTION  object
#  17  APR_RISK_OF_MORTALITY                object
#  18  APR_MEDICAL_SURGICAL_DESCRIPTION     object
#  19  PAYMENT_TYPOLOGY_1                   object
#  20  BIRTH_WEIGHT                         int64
#  21  EMERGENCY_DEPARTMENT_INDICATOR       object
#  22  TOTAL_CHARGES                        object
#  23  TOTAL_COSTS                          object
#  24  REGION                               object
# dtypes: float64(1), int64(2), object(22)
# memory usage: 393.2+ MB
